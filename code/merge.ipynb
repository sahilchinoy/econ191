# %%
import psycopg2
import numpy as np
import pandas as pd
from datetime import date
from fuzzywuzzy import process

# %%
expenditures = pd.read_csv('../data/expenditures.csv')
expenditures.head()
# Out:
#        candidate_name  candidate_id  year office  district         TOT  \
# 0    GAINES, EDWARD T       1265444  2016      S         1   722100.80
# 1    ROWEN, ROBERT J.       1383735  2016      S         1    16827.47
# 2          DODD, BILL       1359048  2016      S         3  4098682.81
# 3   YAMADA, MARIKO M.       1295701  2016      S         3   581241.54
# 4  GALGIANI, CATHLEEN       1273495  2016      S         5  1914684.12
#
#          FND       COMM        ADS       INFO     ...       CONTRIB  \
# 0   53889.23   68719.09       0.00  222241.57     ...      32700.00
# 1     100.00     640.18    5128.00     400.00     ...          0.00
# 2  181669.96  397477.07  886875.00  206297.60     ...      74054.17
# 3    5311.44  147757.78     500.00  258833.45     ...      11750.00
# 4   47866.50  536197.19     577.46  374323.28     ...      16110.00
#
#       GENERAL     LOGTOT     LOGFND    LOGCOMM     LOGADS    LOGINFO  \
# 0   344849.89  13.489920  10.894686  11.137782   0.000000  12.311520
# 1     6268.18   9.730768   4.605170   6.461749   8.542471   5.991465
# 2  1672319.63  15.226176  12.109947  12.892893  13.695459  12.237075
# 3   412402.67  13.272922   8.577618  11.903330   6.214608  12.463940
# 4   958964.43  14.465063  10.776171  13.192257   6.358639  12.832875
#
#    LOGOVERHEAD  LOGCONTRIB  LOGGENERAL
# 0    11.288125   10.395130   12.750864
# 1     8.856966    0.000000    8.743241
# 2    14.230264   11.212552   14.329722
# 3    11.694464    9.371609   12.929756
# 4    13.077864    9.687195   13.773609
#
# [5 rows x 21 columns]

# %%
votes = pd.read_csv('../data/votes.csv', dtype='str')
votes['district'] = votes['district'].apply(lambda s: int(s.split('.')[0]))
votes['year'] = votes['year'].apply(lambda s: int(s))
votes.head()
# Out:
#         candidate office  district party  year   votes total_votes  \
# 0    Abel Guillen      A        18   DEM  2012   74422      150287
# 1       Rob Bonta      A        18   DEM  2012   75865      150287
# 2  Abel Maldonado      S        15   REP  2008  222617      353846
# 3  Jim Fitzgerald      S        15   IND  2008  131229      353846
# 4  Abigail Medina      A        40   DEM  2016   74589      151126
#
#           vote_share winning_votes winner incumbent
# 0  49.51991855582985         75865      0         0
# 1  50.48008144417015         75865      1         0
# 2  62.91352735370754        222617      1         1
# 3  37.08647264629246        222617      0         0
# 4  49.35550467821553         76537      0         0

# %% [markdown]
# ## Match expenditures with votes

# %%
def guess_name(row):
    try:
        # Rearrange into 'First Last'
        # This probably isn't strictly necessary, but makes me feel better
        name_parts = row['candidate_name'].split(',')
        name = name_parts[1] + ' ' + name_parts[0]
        # Get rows from votes data for this race
        district = int(row['district'])
        d = votes[(votes['office'] == row['office']) & (votes['district'] == row['district']) & (votes['year'] == row['year'])]
        choices = d['candidate']
        guess = process.extractOne(name, choices)
        return guess[0]
    except:
        return ''

# %%
expenditures['votes_name'] = expenditures.apply(guess_name, axis=1)

# %%
expenditures.head()
# Out:
#        candidate_name  candidate_id  year office  district         TOT  \
# 0    GAINES, EDWARD T       1265444  2016      S         1   722100.80
# 1    ROWEN, ROBERT J.       1383735  2016      S         1    16827.47
# 2          DODD, BILL       1359048  2016      S         3  4098682.81
# 3   YAMADA, MARIKO M.       1295701  2016      S         3   581241.54
# 4  GALGIANI, CATHLEEN       1273495  2016      S         5  1914684.12
#
#          FND       COMM        ADS       INFO        ...             GENERAL  \
# 0   53889.23   68719.09       0.00  222241.57        ...           344849.89
# 1     100.00     640.18    5128.00     400.00        ...             6268.18
# 2  181669.96  397477.07  886875.00  206297.60        ...          1672319.63
# 3    5311.44  147757.78     500.00  258833.45        ...           412402.67
# 4   47866.50  536197.19     577.46  374323.28        ...           958964.43
#
#       LOGTOT     LOGFND    LOGCOMM     LOGADS    LOGINFO  LOGOVERHEAD  \
# 0  13.489920  10.894686  11.137782   0.000000  12.311520    11.288125
# 1   9.730768   4.605170   6.461749   8.542471   5.991465     8.856966
# 2  15.226176  12.109947  12.892893  13.695459  12.237075    14.230264
# 3  13.272922   8.577618  11.903330   6.214608  12.463940    11.694464
# 4  14.465063  10.776171  13.192257   6.358639  12.832875    13.077864
#
#    LOGCONTRIB  LOGGENERAL         votes_name
# 0   10.395130   12.750864         Ted Gaines
# 1    0.000000    8.743241          Rob Rowen
# 2   11.212552   14.329722          Bill Dodd
# 3    9.371609   12.929756      Mariko Yamada
# 4    9.687195   13.773609  Cathleen Galgiani
#
# [5 rows x 22 columns]

# %%
votes = votes.rename(columns={'candidate': 'votes_name'})
cand_exp_votes = expenditures.merge(votes, on=['votes_name','office','district','year'])
cand_exp_votes.head()
# Out:
#        candidate_name  candidate_id  year office  district         TOT  \
# 0    GAINES, EDWARD T       1265444  2016      S         1   722100.80
# 1    ROWEN, ROBERT J.       1383735  2016      S         1    16827.47
# 2          DODD, BILL       1359048  2016      S         3  4098682.81
# 3   YAMADA, MARIKO M.       1295701  2016      S         3   581241.54
# 4  GALGIANI, CATHLEEN       1273495  2016      S         5  1914684.12
#
#          FND       COMM        ADS       INFO    ...      LOGCONTRIB  \
# 0   53889.23   68719.09       0.00  222241.57    ...       10.395130
# 1     100.00     640.18    5128.00     400.00    ...        0.000000
# 2  181669.96  397477.07  886875.00  206297.60    ...       11.212552
# 3    5311.44  147757.78     500.00  258833.45    ...        9.371609
# 4   47866.50  536197.19     577.46  374323.28    ...        9.687195
#
#    LOGGENERAL         votes_name  party   votes  total_votes  \
# 0   12.750864         Ted Gaines    REP  287314       448816
# 1    8.743241          Rob Rowen    DEM  161502       448816
# 2   14.329722          Bill Dodd    DEM  207927       357628
# 3   12.929756      Mariko Yamada    DEM  149701       357628
# 4   13.773609  Cathleen Galgiani    DEM  174847       308451
#
#            vote_share  winning_votes  winner  incumbent
# 0   64.01598873480447         287314       1          1
# 1  35.984011265195534         287314       0          0
# 2  58.140581833637185         207927       1          0
# 3   41.85941816636281         207927       0          0
# 4   56.68550272166406         174847       1          1
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Race totals

# %%
cand_exp_votes['race_total'] = cand_exp_votes.groupby(['office','district','year']).transform(sum)['TOT']
cand_exp_votes['opposing_total'] = cand_exp_votes['race_total'] - cand_exp_votes['TOT']

# %%
data = cand_exp_votes[(cand_exp_votes['party'] == 'DEM') | (cand_exp_votes['party'] == 'REP')]

# %%
# Was the race contested?
data['contested'] = data.duplicated(subset=['year','office','district'], keep=False).astype(int)
# How many contested races?
print('Total     : {}'.format(len(data)))
print('Contested : {}'.format(len(data[data['contested'] == True])))
# Out:
# Total     : 1518
# Contested : 1438
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.to_csv('../data/all.csv', index=False)

# %%
data['duplicated'] = data.duplicated(['candidate_name','office','district'], keep=False).astype(int)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
duplicates = data[data['duplicated'] == 1]
len(duplicates)
# Out:
# 741

# %%
def find_opposing_candidate(row):
    name = data[(data['year'] == row['year']) & (data['office'] == row['office']) \
               & (data['district'] == row['district']) & \ 
                (data['candidate_name'] != row['candidate_name'])]['candidate_name']
    return name.iloc[0]

# %%
contested = data[data['contested'] == 1]
contested['opposing_candidate'] = contested.apply(find_opposing_candidate, axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
contested.head()
# Out:
#        candidate_name  candidate_id  year office  district         TOT  \
# 0    GAINES, EDWARD T       1265444  2016      S         1   722100.80
# 1    ROWEN, ROBERT J.       1383735  2016      S         1    16827.47
# 2          DODD, BILL       1359048  2016      S         3  4098682.81
# 3   YAMADA, MARIKO M.       1295701  2016      S         3   581241.54
# 4  GALGIANI, CATHLEEN       1273495  2016      S         5  1914684.12
#
#          FND       COMM        ADS       INFO         ...          \
# 0   53889.23   68719.09     100.00  222241.57         ...
# 1     100.00     640.18    5128.00     400.00         ...
# 2  181669.96  397477.07  886875.00  206297.60         ...
# 3    5311.44  147757.78     500.00  258833.45         ...
# 4   47866.50  536197.19     577.46  374323.28         ...
#
#    total_votes          vote_share  winning_votes  winner  incumbent  \
# 0       448816   64.01598873480447         287314       1          1
# 1       448816  35.984011265195534         287314       0          0
# 2       357628  58.140581833637185         207927       1          0
# 3       357628   41.85941816636281         207927       0          0
# 4       308451   56.68550272166406         174847       1          1
#
#     race_total  opposing_total  contested  duplicated  opposing_candidate
# 0       738928         16827.5          1           1    ROWEN, ROBERT J.
# 1       738928          722101          1           0    GAINES, EDWARD T
# 2  4.67992e+06          581242          1           0   YAMADA, MARIKO M.
# 3  4.67992e+06     4.09868e+06          1           0          DODD, BILL
# 4  2.14079e+06          226105          1           1  NAKANISHI, ALAN S.
#
# [5 rows x 34 columns]

# %%
contested['repeat_challenger'] = contested.duplicated(['candidate_name','office','opposing_candidate'], keep=False).astype(int)
contested[contested['repeat_challenger'] == 1].sort_values('candidate_name').head(n=100)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#
# 935        394195         62437.3          1           1
#
#             opposing_candidate  repeat_challenger
# 1418             NUNEZ, FABIAN                  1
# 1656             NUNEZ, FABIAN                  1
# 491        BERNOSKY, ROBERT E.                  1
# 699        BERNOSKY, ROBERT E.                  1
# 1278   CONNOLLY, SHANE PATRICK                  1
# 829    CONNOLLY, SHANE PATRICK                  1
# 584              DENNEY, RALPH                  1
# 804              DENNEY, RALPH                  1
# 1640           MONTANEZ, CINDY                  1
# 1404           MONTANEZ, CINDY                  1
# 1460          MELSH, ROBERT J.                  1
# 1694          MELSH, ROBERT J.                  1
# 1312               TYRONE, RAY                  1
# 1076               TYRONE, RAY                  1
# 492                ALEJO, LUIS                  1
# 700                ALEJO, LUIS                  1
# 1152          CUTHBERT, ROBERT                  1
# 928           CUTHBERT, ROBERT                  1
# 116               LOPEZ, PATTY                  1
# 314               LOPEZ, PATTY                  1
# 286                CHU, KANSEN                  1
# 88                 CHU, KANSEN                  1
# 891              WILSON, ABRAM                  1
# 671              WILSON, ABRAM                  1
# 349          TOPALIAN, RITA H.                  1
# 151          TOPALIAN, RITA H.                  1
# 189             KROUSE, THOMAS                  1
# 385             KROUSE, THOMAS                  1
# 287               BRUNTON, BOB                  1
# 89                BRUNTON, BOB                  1
# ...                        ...                ...
# 476              MULLIN, KEVIN                  1
# 1237       DE VORE, CHARLES S.                  1
# 1007       DE VORE, CHARLES S.                  1
# 500             GROVE, SHANNON                  1
# 305             GROVE, SHANNON                  1
# 279        MOBLEY JR., JACK M.                  1
# 473        MOBLEY JR., JACK M.                  1
# 304   GOODMAN, VIRGINIA "MARI"                  1
# 499   GOODMAN, VIRGINIA "MARI"                  1
# 365             MURATSUCHI, AL                  1
# 169             MURATSUCHI, AL                  1
# 969    PATRICK, GWEN (BATISTE)                  1
# 749    PATRICK, GWEN (BATISTE)                  1
# 1011          JONES, JUDITH E.                  1
# 796           JONES, JUDITH E.                  1
# 865           LOGUE, DANIEL R.                  1
# 640           LOGUE, DANIEL R.                  1
# 331       LARA-GARDNER, JOSEPH                  1
# 527       LARA-GARDNER, JOSEPH                  1
# 659          SIEGLOCK, JACK A.                  1
# 881          SIEGLOCK, JACK A.                  1
# 812             ROACH, DERRICK                  1
# 588             ROACH, DERRICK                  1
# 797              HARKEY, DIANE                  1
# 1012             HARKEY, DIANE                  1
# 716              KNIGHT, STEVE                  1
# 934              KNIGHT, STEVE                  1
# 167        QUIRK-SILVA, SHARON                  1
# 363        QUIRK-SILVA, SHARON                  1
# 935            JONES, LINDA K.                  1
#
# [100 rows x 35 columns]

# %%
contested.to_csv('data/contested.csv', index=False)

# %% [markdown]
# ## Repeat candidates

# %%
identifier_cols = ['candidate_name','office','district','party']
exp_cols = ['CNS','FND','LIT','OFC','PET','PHO','POL','PRT','RAD','SAL','TEL','PRO','WEB']
pct_cols = [exp + '_pct' for exp in exp_cols]
data_cols = ['vote_share','TOT','opposing_total'] + pct_cols

differenced = pd.DataFrame(columns=(identifier_cols + data_cols))

def difference(df):
    """
    Takes a group of observations with the same name and office and
    and adds any *consecutive* repeat elections to a DataFrame.
    """
    
    def compute_difference(pair):
        """
        Compute the difference in expenditures and outcome
        between two consecutive elections.
        """
        
        year1 = pair.iloc[0]['year']
        year2 = pair.iloc[1]['year']
        
        incumbent1 = pair.iloc[0]['incumbent']
        
        if pair.iloc[0]['office'] == 'A' and (year1 - year2 == 2):
            data = pair.iloc[0][data_cols] - pair.iloc[1][data_cols]
            
            data = data.append(pair.iloc[0][identifier_cols])
            data['year1'] = year1
            data['year2'] = year2
            
            data['TOT1']= pair.iloc[0]['TOT']
            data['TOT2']= pair.iloc[1]['TOT']
            
            data['opposing_total1']= pair.iloc[0]['opposing_total']
            data['opposing_total2']= pair.iloc[1]['opposing_total']
            
            data['incumbent1'] = pair.iloc[0]['incumbent']
            data['incumbent2'] = pair.iloc[1]['incumbent']
            
            global differenced
            differenced = differenced.append(data, ignore_index=True)
        
    df = df.sort_values('year', ascending=False)
    
    if len(df) > 1:
        compute_difference(df.iloc[0:2])
    if len(df) > 2:
        compute_difference(df.iloc[1:3])
    if len(df) > 3:
        compute_difference(df.iloc[2:4])
    
    return None

# %%
data['vote_share'] = data['vote_share'].astype(float)
#data[data['contested'] == 1].groupby(['candidate_id','office']).apply(difference)
data.groupby(['candidate_id','office']).apply(difference)
differenced.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          candidate_name office  district party  vote_share         TOT  \
# 0  CALDERON, CHARLES M.      A      58.0   DEM   -1.498600   162575.37
# 1  CALDERON, CHARLES M.      A      58.0   DEM    0.954872    80923.58
# 2        LESLIE, R. TIM      A       4.0   REP    0.116988   496683.68
# 3       KARNETTE, BETTY      A      54.0   DEM    7.274579 -1494454.78
# 4           FOSTER, BEA      A      71.0   DEM    3.959265        0.00
#
#    opposing_total  CNS_pct  FND_pct  LIT_pct   ...    PRO_pct  WEB_pct  \
# 0            0.00      NaN      NaN      NaN   ...        NaN      NaN
# 1            0.00      NaN      NaN      NaN   ...        NaN      NaN
# 2            0.00      NaN      NaN      NaN   ...        NaN      NaN
# 3     -1025161.27      NaN      NaN      NaN   ...        NaN      NaN
# 4       259388.64      NaN      NaN      NaN   ...        NaN      NaN
#
#          TOT1        TOT2  incumbent1  incumbent2  opposing_total1  \
# 0  1079675.44   917100.07           1           1           100.00
# 1   917100.07   836176.49           1           0           100.00
# 2   504978.53     8294.85           1           1           100.00
# 3   357810.03  1852264.81           1           0           100.00
# 4      100.00      100.00           0           0        612298.34
#
#    opposing_total2   year1   year2
# 0           100.00  2010.0  2008.0
# 1           100.00  2008.0  2006.0
# 2           100.00  2004.0  2002.0
# 3       1025261.27  2006.0  2004.0
# 4        352909.70  2004.0  2002.0
#
# [5 rows x 28 columns]

# %%
print(len(differenced))
differenced.to_csv('data/differenced.csv', index=False)
# Out:
# 425
