# %%
import psycopg2
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/all.csv')
# Only Assembly candidates
df = df[df['office'] == 'A']
# In contested races
df = df[df['contested'] == 1]

# %%
df.head()
# Out:
#            candidate_name  candidate_id  year office  district         TOT  \
# 41       GALLAGHER, JAMES       1357069  2016      A         3   595937.61
# 42      RITCHIE, EDWARD H       1383126  2016      A         3    70528.44
# 43  AGUIAR-CURRY, CECILIA       1379566  2016      A         4   752510.86
# 44    SCHAUPP, CHARLES E.       1301596  2016      A         4    44764.57
# 45         BIGELOW, FRANK       1342402  2016      A         5  1399553.97
#
#          FND       COMM        ADS       INFO    ...      party   votes  \
# 41  70177.14   12917.05    2900.00  107178.32    ...        REP  108910
# 42   1600.00   14003.45       0.00   14000.00    ...        DEM   63867
# 43  57234.59  145978.52    5013.05   80725.00    ...        DEM  118772
# 44      0.00    3503.62     975.00   11000.00    ...        REP   68170
# 45  39422.49   56974.95  104229.64   10042.26    ...        REP  121644
#
#     total_votes  vote_share  winning_votes  winner  incumbent  race_total  \
# 41       172777   63.035010         108910       1          1   666466.05
# 42       172777   36.964990         108910       0          0   666466.05
# 43       186942   63.534144         118772       1          0   797275.43
# 44       186942   36.465856         118772       0          0   797275.43
# 45       188593   64.500803         121644       1          1  1399553.97
#
#     opposing_total  contested
# 41        70528.44          1
# 42       595937.61          1
# 43        44764.57          1
# 44       752510.86          1
# 45            0.00          1
#
# [5 rows x 32 columns]

# %%
exp_cols = ['LOGTOT','LOGFND','LOGCOMM','LOGADS','LOGINFO','LOGOVERHEAD','LOGCONTRIB','LOGGENERAL']

# %%
races = pd.DataFrame()

for name, grouped in df.groupby(['district','year']):
    row = {}
    row['district'] = name[0]
    row['year'] = name[1]
    incumbent = grouped[grouped['incumbent'] == 1]
    
    if incumbent.empty:
        dem = grouped[grouped['party'] == 'DEM']
        rep = grouped[grouped['party'] == 'REP']
        
        if len(dem) != 1 or len(rep) != 1:
            continue
        
        dem = dem.iloc[0]
        rep = rep.iloc[0]
        
        row['dem_vote'] = dem['vote_share']
        row['dem_name'] = dem['candidate_name']
        row['rep_name'] = rep['candidate_name']
        row['incumbent'] = 0
        
        for col in exp_cols:
            row['open_' + col] = dem[col] - rep[col]
    else:
        try:
            incumbent = incumbent.iloc[0]
            challenger = grouped[grouped['incumbent'] == 0].iloc[0]
            for col in exp_cols:
                row['incumbent_' + col] = incumbent[col]
                row['challenger_' + col] = challenger[col]
                
            if incumbent['party'] == 'DEM':
                row['dem_vote'] = incumbent['vote_share']
                row['incumbent'] = 1
                row['dem_name'] = incumbent['candidate_name']
                row['rep_name'] = challenger['candidate_name']
            else:
                row['dem_vote'] = challenger['vote_share']
                row['incumbent'] = -1
                row['dem_name'] = challenger['candidate_name']
                row['rep_name'] = incumbent['candidate_name']
        except:
            pass
    races = races.append(row, ignore_index=True)

# %%
races.head(n=20)
# Out:
#                         dem_name   dem_vote  district  incumbent  open_LOGADS  \
# 0                    BERG, PATTY  48.519756       1.0        0.0     3.774325
# 1                    BERG, PATTY  61.442210       1.0        1.0          NaN
# 2                    BERG, PATTY  64.740974       1.0        1.0          NaN
# 3                CHESBRO, WESLEY  70.783007       1.0        0.0    11.437775
# 4                CHESBRO, WESLEY  61.535474       1.0        1.0          NaN
# 5          SMITH, BRIGHAM SAWYER  29.765487       1.0       -1.0          NaN
# 6              KINYON, DOUGLAS J  29.287162       2.0        0.0   -10.227311
# 7            MC IVER, BARBARA G.  35.134665       2.0       -1.0          NaN
# 8                     SMITH, MEL  29.458406       2.0       -1.0          NaN
# 9                 SINGH, PAUL R.  34.601099       2.0        0.0   -11.627626
# 10                WOOD, JAMES D.  65.119680       2.0        0.0     8.138912
# 11               KING, STUART R.  33.851761       3.0        0.0    -9.651600
# 12              WOODS, ROBERT A.  37.242822       3.0       -1.0          NaN
# 13  HARRINGTON, MICHAEL "MICKEY"  38.997213       3.0       -1.0          NaN
# 14  HARRINGTON, MICHAEL "MICKEY"  44.487427       3.0        0.0    -1.026988
# 15  HARRINGTON, MICHAEL "MICKEY"  36.581864       3.0       -1.0          NaN
# 16             ROUSE, CHARLES E.  44.412883       3.0       -1.0          NaN
# 17                     REED, JIM  36.933735       3.0        0.0    -1.153296
# 18             RITCHIE, EDWARD H  36.964990       3.0       -1.0          NaN
# 19          WARREN, DUNCAN SCOTT  33.436202       4.0       -1.0          NaN
#
#     open_LOGCOMM  open_LOGCONTRIB  open_LOGFND  open_LOGGENERAL  open_LOGINFO  \
# 0       1.087902         7.517521    -0.654598         1.387931      1.816492
# 1            NaN              NaN          NaN              NaN           NaN
# 2            NaN              NaN          NaN              NaN           NaN
# 3      10.887677        11.902803    11.435481        12.424489      9.210340
# 4            NaN              NaN          NaN              NaN           NaN
# 5            NaN              NaN          NaN              NaN           NaN
# 6     -12.140721        -8.216088    -9.346902       -12.521355    -10.772061
# 7            NaN              NaN          NaN              NaN           NaN
# 8            NaN              NaN          NaN              NaN           NaN
# 9     -11.749787       -10.423768   -11.055056       -12.997450    -11.843260
# 10     12.146964        11.609553    11.647200        12.783575     10.819778
# 11    -11.659712        -7.813996    -9.983685       -12.138208    -10.429694
# 12           NaN              NaN          NaN              NaN           NaN
# 13           NaN              NaN          NaN              NaN           NaN
# 14     -4.850590        -2.387843   -10.802065        -3.874363    -11.326366
# 15           NaN              NaN          NaN              NaN           NaN
# 16           NaN              NaN          NaN              NaN           NaN
# 17    -11.497074        -6.289155    -9.916707        -1.482613     -1.310486
# 18           NaN              NaN          NaN              NaN           NaN
# 19           NaN              NaN          NaN              NaN           NaN
#
#           ...         challenger_LOGOVERHEAD  challenger_LOGTOT  \
# 0         ...                            NaN                NaN
# 1         ...                       0.000000           0.000000
# 2         ...                       0.000000           0.000000
# 3         ...                            NaN                NaN
# 4         ...                       9.377464          10.953487
# 5         ...                       0.000000           0.000000
# 6         ...                            NaN                NaN
# 7         ...                       9.748533          11.808039
# 8         ...                       6.913598          10.599506
# 9         ...                            NaN                NaN
# 10        ...                            NaN                NaN
# 11        ...                            NaN                NaN
# 12        ...                       0.000000           0.000000
# 13        ...                       0.000000           0.000000
# 14        ...                            NaN                NaN
# 15        ...                       9.684573          10.143364
# 16        ...                       0.000000           8.648435
# 17        ...                            NaN                NaN
# 18        ...                      10.469399          11.163771
# 19        ...                       0.000000           0.000000
#
#    incumbent_LOGADS  incumbent_LOGCOMM  incumbent_LOGCONTRIB  \
# 0               NaN                NaN                   NaN
# 1         11.422845          10.781044             11.655726
# 2          4.605170           7.859757             12.142334
# 3               NaN                NaN                   NaN
# 4         12.003510           8.256820             11.622139
# 5          9.399868           9.823887             11.709110
# 6               NaN                NaN                   NaN
# 7         11.412949          11.117184             10.798082
# 8         10.025492           6.446862             11.384111
# 9               NaN                NaN                   NaN
# 10              NaN                NaN                   NaN
# 11              NaN                NaN                   NaN
# 12        10.855457           9.932751             11.994753
# 13        11.363287          10.006032             11.722153
# 14              NaN                NaN                   NaN
# 15         8.222253          10.508895             10.671936
# 16        11.470906          11.451557             10.690482
# 17              NaN                NaN                   NaN
# 18         7.972466           9.466303             12.094060
# 19         0.000000           0.000000              0.000000
#
#     incumbent_LOGFND  incumbent_LOGGENERAL  incumbent_LOGINFO  \
# 0                NaN                   NaN                NaN
# 1          10.880901             12.237147           9.523325
# 2          11.133727             11.213601           8.006368
# 3                NaN                   NaN                NaN
# 4          11.716772             12.576918           0.000000
# 5          10.840674             12.260787          11.772482
# 6                NaN                   NaN                NaN
# 7          11.171209             12.701702          11.507384
# 8          11.598762             12.190836          11.078863
# 9                NaN                   NaN                NaN
# 10               NaN                   NaN                NaN
# 11               NaN                   NaN                NaN
# 12         11.479897             12.125601           9.640498
# 13         11.732481             12.441956           9.922868
# 14               NaN                   NaN                NaN
# 15         11.223436             12.166193          11.250957
# 16         11.292838             12.847659          11.605693
# 17               NaN                   NaN                NaN
# 18         11.158778             12.171339          11.582249
# 19          0.000000              0.000000           0.000000
#
#     incumbent_LOGOVERHEAD  incumbent_LOGTOT
# 0                     NaN               NaN
# 1               11.441491         12.963296
# 2               10.617812         12.652464
# 3                     NaN               NaN
# 4               11.600413         13.158832
# 5               11.637373         13.090133
# 6                     NaN               NaN
# 7               11.495184         13.285304
# 8               11.318409         13.606732
# 9                     NaN               NaN
# 10                    NaN               NaN
# 11                    NaN               NaN
# 12              11.653892         13.376377
# 13              11.746228         13.653669
# 14                    NaN               NaN
# 15              11.653282         12.862850
# 16              12.194448         13.518764
# 17                    NaN               NaN
# 18              11.960887         13.297891
# 19               0.000000          9.023390
#
# [20 rows x 30 columns]

# %%
races['incumbent'] = races['incumbent'].astype(int)
races['district'] = races['district'].astype(int)
races['year'] = races['year'].astype(int)

# %%
votes = pd.read_csv('../data/votes.csv')
votes = votes[(votes['office'] == 'A') & (votes['party'] == 'DEM')]
votes = votes.groupby(['district','year'])['vote_share'].sum().reset_index()
votes = votes[['district','vote_share']].groupby('district').mean().reset_index()

# %%
votes = votes.rename(columns={'vote_share': 'avg_vote'})
votes.head()
# Out:
#    district   avg_vote
# 0         1  56.131151
# 1         2  52.360746
# 2         3  38.684087
# 3         4  46.542772
# 4         5  37.511392

# %%
races = races.merge(votes, on='district')

# %%
races = races.fillna(0)

# %%
races.head()
# Out:
#           dem_name   dem_vote  district  incumbent  open_LOGADS  open_LOGCOMM  \
# 0      BERG, PATTY  48.519756         1          0     3.774325      1.087902
# 1      BERG, PATTY  61.442210         1          1     0.000000      0.000000
# 2      BERG, PATTY  64.740974         1          1     0.000000      0.000000
# 3  CHESBRO, WESLEY  70.783007         1          0    11.437775     10.887677
# 4  CHESBRO, WESLEY  61.535474         1          1     0.000000      0.000000
#
#    open_LOGCONTRIB  open_LOGFND  open_LOGGENERAL  open_LOGINFO    ...      \
# 0         7.517521    -0.654598         1.387931      1.816492    ...
# 1         0.000000     0.000000         0.000000      0.000000    ...
# 2         0.000000     0.000000         0.000000      0.000000    ...
# 3        11.902803    11.435481        12.424489      9.210340    ...
# 4         0.000000     0.000000         0.000000      0.000000    ...
#
#    challenger_LOGTOT  incumbent_LOGADS incumbent_LOGCOMM  \
# 0           0.000000          0.000000          0.000000
# 1           0.000000         11.422845         10.781044
# 2           0.000000          4.605170          7.859757
# 3           0.000000          0.000000          0.000000
# 4          10.953487         12.003510          8.256820
#
#    incumbent_LOGCONTRIB  incumbent_LOGFND  incumbent_LOGGENERAL  \
# 0              0.000000          0.000000              0.000000
# 1             11.655726         10.880901             12.237147
# 2             12.142334         11.133727             11.213601
# 3              0.000000          0.000000              0.000000
# 4             11.622139         11.716772             12.576918
#
#    incumbent_LOGINFO  incumbent_LOGOVERHEAD  incumbent_LOGTOT   avg_vote
# 0           0.000000               0.000000          0.000000  56.131151
# 1           9.523325              11.441491         12.963296  56.131151
# 2           8.006368              10.617812         12.652464  56.131151
# 3           0.000000               0.000000          0.000000  56.131151
# 4           0.000000              11.600413         13.158832  56.131151
#
# [5 rows x 31 columns]

# %%
races.to_csv('../data/races.csv', index=False)
